# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import pandas as pd
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Read hypertension csv file
htn_read = pd.read_csv('resources/hypertension_data.csv')

htn_read.head()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  57.0  1.0   3       145   233    1        0      150      0      2.3
# 1  64.0  0.0   2       130   250    0        1      187      0      3.5
# 2  52.0  1.0   1       130   204    0        0      172      0      1.4
# 3  56.0  0.0   1       120   236    0        1      178      0      0.8
# 4  66.0  0.0   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
htn_read.count()
# Out:
# age         26083
# sex         26058
# cp          26083
# trestbps    26083
# chol        26083
# fbs         26083
# restecg     26083
# thalach     26083
# exang       26083
# oldpeak     26083
# slope       26083
# ca          26083
# thal        26083
# target      26083
# dtype: int64

# %%
htn_read.nunique()
# Out:
# age          88
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
# Checked for missing values then,
# Determine unique values
for x in htn_read.columns:
    print(x, len(htn_read[x].unique()))
# Out:
# age 88
# sex 3
# cp 4
# trestbps 49
# chol 152
# fbs 2
# restecg 3
# thalach 91
# exang 2
# oldpeak 40
# slope 3
# ca 5
# thal 4
# target 2

# %%
htn_read['age'].value_counts().sort_index()
# Out:
# age
# 11.0    1
# 12.0    2
# 13.0    2
# 14.0    2
# 15.0    3
#        ..
# 94.0    6
# 95.0    6
# 96.0    3
# 97.0    4
# 98.0    2
# Name: count, Length: 88, dtype: int64

# %%
htn_read["age_category"] = np.where(htn_read['age']<=44, "18-44",
                           np.where(htn_read['age']<=59, "45-59",
                           np.where(htn_read['age']<=69, "60-69", "70+")))
del htn_read['age']
htn_read
# Out:
#        sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      1.0   3       145   233    1        0      150      0      2.3      0
# 1      0.0   2       130   250    0        1      187      0      3.5      0
# 2      1.0   1       130   204    0        0      172      0      1.4      2
# 3      0.0   1       120   236    0        1      178      0      0.8      2
# 4      0.0   0       120   354    0        1      163      1      0.6      2
# ...    ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 26078  0.0   0       138   294    1        1      106      0      1.9      1
# 26079  1.0   0       144   200    0        0      126      1      0.9      1
# 26080  1.0   0       100   234    0        1      156      0      0.1      2
# 26081  1.0   1       154   232    0        0      164      0      0.0      2
# 26082  0.0   1       130   236    0        0      174      0      0.0      1
#
#        ca  thal  target age_category
# 0       0     1       1        45-59
# 1       0     2       1        60-69
# 2       0     2       1        45-59
# 3       0     2       1        45-59
# 4       0     2       1        60-69
# ...    ..   ...     ...          ...
# 26078   3     2       0          70+
# 26079   0     3       0        60-69
# 26080   1     3       0        60-69
# 26081   1     2       0        60-69
# 26082   1     2       0        60-69
#
# [26083 rows x 14 columns]

# %%
htn_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26083 entries, 0 to 26082
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sex           26058 non-null  float64
#  1   cp            26083 non-null  int64
#  2   trestbps      26083 non-null  int64
#  3   chol          26083 non-null  int64
#  4   fbs           26083 non-null  int64
#  5   restecg       26083 non-null  int64
#  6   thalach       26083 non-null  int64
#  7   exang         26083 non-null  int64
#  8   oldpeak       26083 non-null  float64
#  9   slope         26083 non-null  int64
#  10  ca            26083 non-null  int64
#  11  thal          26083 non-null  int64
#  12  target        26083 non-null  int64
#  13  age_category  26083 non-null  object
# dtypes: float64(2), int64(11), object(1)
# memory usage: 2.8+ MB

# %%
htn_read = htn_read.dropna()

# %%
dummies_htn_df = pd.get_dummies(htn_read, dtype=int)
dummies_htn_df
# Out:
#        sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      1.0   3       145   233    1        0      150      0      2.3      0
# 1      0.0   2       130   250    0        1      187      0      3.5      0
# 2      1.0   1       130   204    0        0      172      0      1.4      2
# 3      0.0   1       120   236    0        1      178      0      0.8      2
# 4      0.0   0       120   354    0        1      163      1      0.6      2
# ...    ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 26078  0.0   0       138   294    1        1      106      0      1.9      1
# 26079  1.0   0       144   200    0        0      126      1      0.9      1
# 26080  1.0   0       100   234    0        1      156      0      0.1      2
# 26081  1.0   1       154   232    0        0      164      0      0.0      2
# 26082  0.0   1       130   236    0        0      174      0      0.0      1
#
#        ca  thal  target  age_category_18-44  age_category_45-59  \
# 0       0     1       1                   0                   1
# 1       0     2       1                   0                   0
# 2       0     2       1                   0                   1
# 3       0     2       1                   0                   1
# 4       0     2       1                   0                   0
# ...    ..   ...     ...                 ...                 ...
# 26078   3     2       0                   0                   0
# 26079   0     3       0                   0                   0
# 26080   1     3       0                   0                   0
# 26081   1     2       0                   0                   0
# 26082   1     2       0                   0                   0
#
#        age_category_60-69  age_category_70+
# 0                       0                 0
# 1                       1                 0
# 2                       0                 0
# 3                       0                 0
# 4                       1                 0
# ...                   ...               ...
# 26078                   0                 1
# 26079                   1                 0
# 26080                   1                 0
# 26081                   1                 0
# 26082                   1                 0
#
# [26058 rows x 17 columns]

# %%
# Split the data
y = dummies_htn_df["target"]
X = dummies_htn_df.drop("target", axis=1)

# %%
y.value_counts()
# Out:
# target
# 1    14274
# 0    11784
# Name: count, dtype: int64

# %%
# Splitting the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1)

# %% [markdown]
# **Logistic Regression Model 98% accuracy**

# %%
# Train Model
clf = LogisticRegression(random_state=1,max_iter=1000)
clf.fit(X_train, y_train)
# Make predictions
predictions = clf.predict(X_test)

print(accuracy_score(y_test,predictions))
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
# 0.8615502686108979
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      2984
#            1       0.84      0.93      0.88      3531
#
#     accuracy                           0.86      6515
#    macro avg       0.87      0.86      0.86      6515
# weighted avg       0.87      0.86      0.86      6515
#
# [[2339  645]
#  [ 257 3274]]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Normalize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network
model = Sequential()
model.add(Dense(60, input_shape=(X_train.shape[1],), activation="relu"))
model.add(BatchNormalization())
model.add(Dense(120, activation="relu"))
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(1, activation="sigmoid"))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Make predictions
predictions = model.predict(X_test_scaled)
predictions = (predictions > 0.5).astype(int)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, predictions))
print("Classification Report:")
print(classification_report(y_test, predictions))
print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))
# Out:
# Epoch 1/100
# 489/489 [==============================] - 4s 5ms/step - loss: 0.2483 - accuracy: 0.8988 - val_loss: 0.1609 - val_accuracy: 0.9353
# Epoch 2/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0949 - accuracy: 0.9632 - val_loss: 0.0302 - val_accuracy: 0.9910
# Epoch 3/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0410 - accuracy: 0.9850 - val_loss: 0.0115 - val_accuracy: 0.9990
# Epoch 4/100
# 489/489 [==============================] - 2s 5ms/step - loss: 0.0195 - accuracy: 0.9941 - val_loss: 0.0031 - val_accuracy: 0.9992
# Epoch 5/100
# 489/489 [==============================] - 3s 7ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.0040 - val_accuracy: 0.9990
# Epoch 6/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 7/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 3.4903e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 2.6267e-04 - val_accuracy: 1.0000
# Epoch 9/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 6.3336e-04 - val_accuracy: 0.9997
# Epoch 10/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 2.7859e-04 - val_accuracy: 1.0000
# Epoch 11/100
# 489/489 [==============================] - 3s 6ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 3.8054e-05 - val_accuracy: 1.0000
# Epoch 12/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 1.4315e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 6.5753e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 6.8354e-06 - val_accuracy: 1.0000
# Epoch 15/100
# 489/489 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 1.2838e-05 - val_accuracy: 1.0000
# Epoch 16/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 17/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 9.7439e-05 - val_accuracy: 1.0000
# Epoch 18/100
# 489/489 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 7.0362e-06 - val_accuracy: 1.0000
# Epoch 19/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 1.5289e-04 - val_accuracy: 1.0000
# Epoch 20/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 2.4954e-05 - val_accuracy: 1.0000
# Epoch 21/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 3.6986e-06 - val_accuracy: 1.0000
# Epoch 22/100
# Epoch 83/100
# 489/489 [==============================] - 2s 4ms/step - loss: 4.4503e-05 - accuracy: 1.0000 - val_loss: 1.2811e-07 - val_accuracy: 1.0000
# Epoch 84/100
# 489/489 [==============================] - 2s 4ms/step - loss: 1.2590e-05 - accuracy: 1.0000 - val_loss: 4.7719e-08 - val_accuracy: 1.0000
# Epoch 85/100
# 489/489 [==============================] - 2s 4ms/step - loss: 2.3727e-05 - accuracy: 1.0000 - val_loss: 1.1612e-08 - val_accuracy: 1.0000
# Epoch 86/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 1.9768e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 489/489 [==============================] - 3s 6ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 2.7766e-06 - val_accuracy: 1.0000
# Epoch 88/100
# 489/489 [==============================] - 3s 5ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 4.4552e-07 - val_accuracy: 1.0000
# Epoch 89/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 1.0152e-07 - val_accuracy: 1.0000
# Epoch 90/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 1.2982e-07 - val_accuracy: 1.0000
# Epoch 91/100
# 489/489 [==============================] - 2s 4ms/step - loss: 1.0117e-04 - accuracy: 1.0000 - val_loss: 1.7495e-07 - val_accuracy: 1.0000
# Epoch 92/100
# 489/489 [==============================] - 2s 4ms/step - loss: 9.0779e-04 - accuracy: 0.9998 - val_loss: 2.6600e-07 - val_accuracy: 1.0000
# Epoch 93/100
# 489/489 [==============================] - 2s 5ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 2.1727e-06 - val_accuracy: 1.0000
# Epoch 94/100
# 489/489 [==============================] - 3s 6ms/step - loss: 3.1755e-04 - accuracy: 0.9999 - val_loss: 8.9086e-08 - val_accuracy: 1.0000
# Epoch 95/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 1.1670e-06 - val_accuracy: 1.0000
# Epoch 96/100
# 489/489 [==============================] - 2s 4ms/step - loss: 8.9276e-04 - accuracy: 0.9998 - val_loss: 1.3998e-07 - val_accuracy: 1.0000
# Epoch 97/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 1.4526e-07 - val_accuracy: 1.0000
# Epoch 98/100
# 489/489 [==============================] - 2s 4ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 1.5037e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 489/489 [==============================] - 2s 4ms/step - loss: 4.5940e-04 - accuracy: 0.9999 - val_loss: 1.1550e-07 - val_accuracy: 1.0000
# Epoch 100/100
# 489/489 [==============================] - 3s 7ms/step - loss: 4.0805e-04 - accuracy: 0.9999 - val_loss: 4.7285e-08 - val_accuracy: 1.0000
# 204/204 [==============================] - 1s 2ms/step
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2984
#            1       1.00      1.00      1.00      3531
#
#     accuracy                           1.00      6515
#    macro avg       1.00      1.00      1.00      6515
# weighted avg       1.00      1.00      1.00      6515
#
# Confusion Matrix:
# [[2984    0]
#  [   0 3531]]
